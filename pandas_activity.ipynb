# %% [markdown]
# # **IMPORTING PANDAS AND LOADING DATASET**

# %%
import pandas as pd
df = pd.read_csv("/content/Mobiles Dataset (2025).csv", encoding="ISO-8859-1")

# %% [markdown]
# # New Section

# %% [markdown]
# ## **BASIC PANDAS FUCNTION**

# %%
#df.head()
#  df.tail()
#  df.info()
# df.shape
# df.columns
# df.dtypes
# df.nunique()
# df.isnull().sum()
# df.duplicated()
# Out:
#   Company Name            Model Name Mobile Weight  RAM Front Camera  \
# 0        Apple       iPhone 16 128GB          174g  6GB         12MP
# 1        Apple       iPhone 16 256GB          174g  6GB         12MP
# 2        Apple       iPhone 16 512GB          174g  6GB         12MP
# 3        Apple  iPhone 16 Plus 128GB          203g  6GB         12MP
# 4        Apple  iPhone 16 Plus 256GB          203g  6GB         12MP
#
#   Back Camera   Processor Battery Capacity Screen Size  \
# 0        48MP  A17 Bionic         3,600mAh  6.1 inches
# 1        48MP  A17 Bionic         3,600mAh  6.1 inches
# 2        48MP  A17 Bionic         3,600mAh  6.1 inches
# 3        48MP  A17 Bionic         4,200mAh  6.7 inches
# 4        48MP  A17 Bionic         4,200mAh  6.7 inches
#
#   Launched Price (Pakistan) Launched Price (India) Launched Price (China)  \
# 0               PKR 224,999             INR 79,999              CNY 5,799
# 1               PKR 234,999             INR 84,999              CNY 6,099
# 2               PKR 244,999             INR 89,999              CNY 6,499
# 3               PKR 249,999             INR 89,999              CNY 6,199
# 4               PKR 259,999             INR 94,999              CNY 6,499
#
#   Launched Price (USA) Launched Price (Dubai)  Launched Year
# 0              USD 799              AED 2,799           2024
# 1              USD 849              AED 2,999           2024
# 2              USD 899              AED 3,199           2024
# 3              USD 899              AED 3,199           2024
# 4              USD 949              AED 3,399           2024

# %% [markdown]
# # **Data selection**

# %%
#df['Model Name']
#df[['Company Name','Model Name']]
#df.iloc[0]
#df.loc[df['Company Name']=='Apple']
# df[(df['Company Name']=='Apple') & (df['Launched Year']>=2021)]
# df.at[0,'Company Name']
#df.sample()
# Out:
#     Company Name               Model Name Mobile Weight   RAM Front Camera  \
# 896         POCO              M2 Pro 64GB          209g   4GB         16MP
# 917         POCO                 X6 128GB          193g   6GB         16MP
# 330         Oppo         Reno13 Pro 512GB          210g  12GB         50MP
# 10         Apple  iPhone 16 Pro Max 256GB          221g   8GB    12MP / 4K
# 63         Apple       iPhone 11 Pro 64GB          188g   4GB    12MP / 4K
# ..           ...                      ...           ...   ...          ...
# 895         POCO             F2 Pro 128GB          219g   6GB         20MP
# 311         Vivo                X80 256GB          206g  12GB         32MP
# 118      Samsung    Galaxy Z Flip 5 512GB          187g   8GB         12MP
# 349         Oppo                A60 256GB          186g   8GB          8MP
# 347         Oppo                 A3 128GB          186g   4GB          5MP
#
#             Back Camera                Processor Battery Capacity  \
# 896                48MP          Snapdragon 720G          5000mAh
# 917                64MP  MediaTek Dimensity 8100          5000mAh
# 330   50MP + 50MP + 8MP  MediaTek Dimensity 8350          5800mAh
# 10          48MP + 12MP                  A17 Pro         4,500mAh
# 63   12MP + 12MP + 12MP               A13 Bionic         3,046mAh
# ..                  ...                      ...              ...
# 895                64MP           Snapdragon 865          4700mAh
# 311                50MP  MediaTek Dimensity 9000          4700mAh
# 118         12MP + 12MP       Snapdragon 8 Gen 2          3700mAh
# 349          50MP + 2MP        Snapdragon 680 4G          5000mAh
# 347                50MP   Snapdragon 6s 4G Gen 1          5000mAh
#
#      Screen Size Launched Price (Pakistan) Launched Price (India)  \
# 896  6.67 inches                PKR 34,999             INR 13,999
# 917  6.67 inches                PKR 59,999             INR 21,999
# 330  6.83 inches               PKR 129,999             INR 69,999
# 10    6.7 inches               PKR 324,999            INR 114,999
# 63    5.8 inches               PKR 219,999             INR 99,900
# ..           ...                       ...                    ...
# 895  6.67 inches                PKR 99,999             INR 37,999
# 311  6.78 inches               PKR 179,999             INR 59,999
# 118   6.7 inches               PKR 380,000            INR 104,900
# 349  6.67 inches                PKR 74,999             INR 42,999
# 347   6.7 inches                PKR 59,999             INR 34,999
#
#     Launched Price (China) Launched Price (USA) Launched Price (Dubai)  \
# 896              CNY 1,399              USD 199                AED 799
# 917              CNY 2,299              USD 349              AED 1,299
# 330              CNY 5,999              USD 799              AED 2,999
# 10               CNY 7,799            USD 1,199              AED 3,999
# 63               CNY 6,999              USD 999              AED 3,799
# ..                     ...                  ...                    ...
# 895              CNY 2,999              USD 499              AED 1,999
# 311              CNY 5,999              USD 899              AED 3,499
# 118              CNY 8,999            USD 1,099              AED 4,399
# 349              CNY 3,499              USD 499              AED 1,899
# 347              CNY 2,999              USD 399              AED 1,499
#
#      Launched Year
# 896           2020
# 917           2024
# 330           2025
# 10            2024
# 63            2019
# ..             ...
# 895           2020
# 311           2022
# 118           2023
# 349           2024
# 347           2024
#
# [186 rows x 15 columns]

# %% [markdown]
# ## **Sorting and ordering**

# %%
# df.sort_values(by='Launched Year',ascending=False)
# df.sort_values(by=['Company Name','Launched Year'],ascending=[True,False])
# df.sort_index()

# %% [markdown]
# # **Aggregation and stat**

# %%
# df.sum()
# df['Launched Year'].mean()
# df['Launched Year'].median()
# df['Launched Year'].mode()
# df['Launched Year'].min()
# df['Launched Year'].max()
# df['Launched Year'].std()
# df['Launched Year'].var()
#df['Launched Year'].count()
# Out:
# 930

# %% [markdown]
# ## **Data tranformation**

# %%
# df['Launched Year']=df['Launched Year']-2
# print(df['Launched Year'])
# df['Company Name'].replace({'Apple':'Apple_company'})
# df.drop_duplicates()
df.drop('RAM',axis=1)

# %% [markdown]
# ## **Filling missing data**

# %%
# df.fillna(0)
df.dropna()

# %% [markdown]
# # **Data exporting**

# %%
# df.to_csv('phone_file.csv',index=False)
# df.to_excel('phone_file.xlsx',index=False)
#df.to_json('phone_file.json')

# %% [markdown]
# # **String operation**

# %%
# df['Company Name'].str.upper()
# df['Company Name'].str.lower()
# df['Company Name'].str.startswith('L')
# df['Company Name'].str.endswith('e')
# df['Company Name'].str.replace('Apple','orange')
# df['Company Name'].str.split(' ')
df['Company Name'].str.len()
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 925    4
# 926    4
# 927    7
# 928    7
# 929    7
# Name: Company Name, Length: 930, dtype: int64

# %% [markdown]
# # **HANDLE MISSING DATA**

# %%
# df.fillna(0)
# df.dropna()
