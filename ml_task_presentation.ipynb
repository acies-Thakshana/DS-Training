# %%
# Import required libraries
import pandas as pd
import numpy as np


file_path = "kidney_disease.csv"
df = pd.read_csv(file_path)

print(df.head())

print(df.info())

# Check for missing values
print(df.isnull().sum())

# %%
# Drop 'id' column if it exists
if 'id' in df.columns:
    df.drop(columns=['id'], inplace=True)

for column in df.columns:
    for i in range(len(df[column])):
        if isinstance(df[column][i], str):
            df[column][i] = df[column][i].strip().lower()





numeric_cols = ["pcv", "wc", "rc"]
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Check if missing values still exist
print(df.isnull().sum())
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[column][i] = df[column][i].strip().lower()
# <ipython-input-5-8986a32c1735>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column][i] = df[column][i].strip().lower()
# <ipython-input-5-8986a32c1735>:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...

# %%
from sklearn.impute import SimpleImputer

num_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

df[num_cols] = df[num_cols].bfill().ffill()

# Use SimpleImputer to fill any remaining NaNs in numerical data
num_imputer = SimpleImputer(strategy="median")
df[num_cols] = num_imputer.fit_transform(df[num_cols])

# Apply Mode (Most Frequent) Imputation for categorical variables
cat_imputer = SimpleImputer(strategy="most_frequent")
df[cat_cols] = cat_imputer.fit_transform(df[cat_cols])

print("Missing values after filling:", df.isnull().sum().sum())
# Out:
# Missing values after filling: 0

# %%
df.head()
# Out:
#     id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  0.0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent  notpresent
# 1  1.0   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent  notpresent
# 2  2.0  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  3.0  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  4.0  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  5.2   no   no   no  good   no   no            ckd
# 2  ...   31  7500  5.2   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
# One-hot encoding for categorical variables
df = pd.get_dummies(df, columns=['hemo_category', 'bp_category'], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-10f18e0d05ee> in <cell line: 0>()
#       1 # One-hot encoding for categorical variables
# ----> 2 df = pd.get_dummies(df, columns=['hemo_category', 'bp_category'], drop_first=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# ...

# %%
df.head()
# Out:
#     id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  0.0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent  notpresent
# 1  1.0   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent  notpresent
# 2  2.0  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  3.0  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  4.0  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  5.2   no   no   no  good   no   no            ckd
# 2  ...   31  7500  5.2   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df["age_group"] = pd.cut(df["age"], bins=[0, 30, 60, float("inf")], labels=["Young", "Middle-Aged", "Senior"])

# Convert to integer encoding
df["age_group"] = df["age_group"].replace({"Young": 0, "Middle-Aged": 1, "Senior": 2}).astype(int)

print(df["age_group"].value_counts())
# Out:
# age_group
# 1    212
# 2    136
# 0     52
# Name: count, dtype: int64
# <ipython-input-13-cd1f32521dc3>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["age_group"] = df["age_group"].replace({"Young": 0, "Middle-Aged": 1, "Senior": 2}).astype(int)
# <ipython-input-13-cd1f32521dc3>:4: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["age_group"] = df["age_group"].replace({"Young": 0, "Middle-Aged": 1, "Senior": 2}).astype(int)

# %%
df.head()
# Out:
#     id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  0.0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent  notpresent
# 1  1.0   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent  notpresent
# 2  2.0  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  3.0  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  4.0  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  5.2   no   no   no  good   no   no            ckd
# 2  ...   31  7500  5.2   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

num_cols = ["bp", "sg", "al", "su", "bgr", "bu", "sc", "sod", "pot", "hemo", "pcv", "wc", "rc"]

# Initialize scalers
standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()

df[num_cols] = standard_scaler.fit_transform(df[num_cols])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-db75f82b8657> in <cell line: 0>()
#       7 minmax_scaler = MinMaxScaler()
#       8
# ----> 9 df[num_cols] = standard_scaler.fit_transform(df[num_cols])
#      10
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
# ...

# %%
print(df[num_cols].describe())

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=["classification"])  # Drop the target column
y = df["classification"]  # Target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print(f"Training set: {X_train.shape}, Testing set: {X_test.shape}")
# Out:
# Training set: (280, 26), Testing set: (120, 26)

# %%
from sklearn.preprocessing import LabelEncoder

categorical_cols = ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']

label_enc = LabelEncoder()
for col in categorical_cols:
    X_train[col] = label_enc.fit_transform(X_train[col])
    X_test[col] = label_enc.transform(X_test[col])

print(X_train.head())
# Out:
#         id   age    bp     sg   al   su  rbc  pc  pcc  ba  ...  pcv     wc  \
# 147  147.0  60.0  60.0  1.010  3.0  1.0    1   0    1   0  ...   25  15200
# 346  346.0  33.0  60.0  1.025  0.0  0.0    1   1    0   0  ...   52   4300
# 279  279.0  24.0  70.0  1.025  0.0  0.0    1   1    0   0  ...   48   5800
# 255  255.0  34.0  80.0  1.025  0.0  0.0    1   1    0   0  ...   52   9200
# 74    74.0  56.0  90.0  1.015  2.0  0.0    0   0    0   0  ...   29   6400
#
#       rc  htn  dm  cad appet pe ane  age_group
# 147  3.0    1   3    1     1  0   1          1
# 346  5.8    0   3    1     0  0   0          1
# 279  5.6    0   3    1     0  0   0          0
# 255  6.3    0   3    1     0  0   0          1
# 74   3.4    1   3    1     0  0   0          1
#
# [5 rows x 26 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize Logistic Regression model
log_model = LogisticRegression(max_iter=500, random_state=42)

log_model.fit(X_train, y_train)

y_pred = log_model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-280cd3cbd530> in <cell line: 0>()
#       5 log_model = LogisticRegression(max_iter=500, random_state=42)
#       6
# ----> 7 log_model.fit(X_train, y_train)
#       8
#       9 y_pred = log_model.predict(X_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# -> 1222         X, y = validate_data(
#    1223             self,
#    1224             X,
#
# ...

# %%
# Accuracy Score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

print("Classification Report:\n", classification_report(y_test, y_pred))

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42,class_weight='balanced')

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)

# Accuracy Score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-44510e9105da> in <cell line: 0>()
#       6
#       7 # Train the model
# ----> 8 rf_model.fit(X_train, y_train)
#       9
#      10 # Make predictions
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize SVM model
svm_model = SVC(kernel='rbf', C=1.0, random_state=42)

# Train the model
svm_model.fit(X_train, y_train)

# Make predictions
y_pred = svm_model.predict(X_test)

# Accuracy Score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

# Classification Report
print("Classification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# %%
import pandas as pd

#  display actual vs predicted values
df_results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

print(df_results.head(20))

# %%
#  class distribution after cleaning
print("\nClass Distribution After Cleaning:")
print(df['classification'].value_counts(normalize=True) * 100)
# Out:
# Class Distribution After Cleaning:
# classification
# ckd       62.0
# notckd    37.5
# ckd\t      0.5
# Name: proportion, dtype: float64

# %%
df_numeric = df.copy()
df_numeric['classification'] = df_numeric['classification'].astype('category').cat.codes  # Convert target to 0 and 1


correlation_hemo = df_numeric['hemo'].corr(df_numeric['classification'])
correlation_sg = df_numeric['sg'].corr(df_numeric['classification'])


print(f"Correlation of Hemoglobin (hemo) with target: {correlation_hemo:.3f}")
print(f"Correlation of Specific Gravity (sg) with target: {correlation_sg:.3f}")
# Out:
# Correlation of Hemoglobin (hemo) with target: 0.748
# Correlation of Specific Gravity (sg) with target: 0.719
