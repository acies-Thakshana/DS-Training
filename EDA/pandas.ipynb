# %%
import pandas as pd

# %%
df=pd.read_excel("sales-data.xlsx",sheet_name="Sales - Data")
df.head()
# Out:
#     Order ID        Country Sales Channel Order Priority Order Date  \
# 0  530075585       Ethiopia        Online              H 2010-06-06
# 1  360841929         Sweden        Online              L 2012-10-02
# 2  932613790       Maldives       Offline              C 2017-07-28
# 3  241891753  Cote d'Ivoire        Online              C 2010-04-23
# 4  707318103        Romania        Online              M 2016-03-16
#
#    Ship Date  Units Sold  Unit Price  Unit Cost      Sales             Item
# 0 2010-07-01       10000      152.58      97.44  1525800.0           Snacks
# 1 2012-10-20       10000      651.21     524.96  6512100.0  Office Supplies
# 2 2017-08-13       10000       47.45      31.79   474500.0        Beverages
# 3 2010-04-26       10000      152.58      97.44  1525800.0           Snacks
# 4 2016-05-03       10000      437.20     263.33  4372000.0        Cosmetics

# %% [markdown]
# size of dataframe

# %%
df.shape
# Out:
# (499999, 12)

# %% [markdown]
# checking the data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499999 entries, 0 to 499998
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Order ID        499999 non-null  int64
#  1   Country         499999 non-null  object
#  2   Sales Channel   499999 non-null  object
#  3   Order Priority  499999 non-null  object
#  4   Order Date      499999 non-null  datetime64[ns]
#  5   Ship Date       499999 non-null  datetime64[ns]
#  6   Units Sold      499999 non-null  int64
#  7   Unit Price      499999 non-null  float64
#  8   Unit Cost       499999 non-null  float64
#  9   Sales           499999 non-null  float64
#  10  Item            499999 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(2), object(4)
# memory usage: 42.0+ MB

# %%
df.isna().sum()
# Out:
# Order ID          0
# Country           0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Sales             0
# Item              0
# dtype: int64

# %% [markdown]
# Add a column Profit

# %%
df["profit"]=df["Sales"]-(df["Units Sold"]*df["Unit Cost"])
df.head()
# Out:
#     Order ID        Country Sales Channel Order Priority Order Date  \
# 0  530075585       Ethiopia        Online              H 2010-06-06
# 1  360841929         Sweden        Online              L 2012-10-02
# 2  932613790       Maldives       Offline              C 2017-07-28
# 3  241891753  Cote d'Ivoire        Online              C 2010-04-23
# 4  707318103        Romania        Online              M 2016-03-16
#
#    Ship Date  Units Sold  Unit Price  Unit Cost      Sales             Item  \
# 0 2010-07-01       10000      152.58      97.44  1525800.0           Snacks
# 1 2012-10-20       10000      651.21     524.96  6512100.0  Office Supplies
# 2 2017-08-13       10000       47.45      31.79   474500.0        Beverages
# 3 2010-04-26       10000      152.58      97.44  1525800.0           Snacks
# 4 2016-05-03       10000      437.20     263.33  4372000.0        Cosmetics
#
#       profit
# 0   551400.0
# 1  1262500.0
# 2   156600.0
# 3   551400.0
# 4  1738700.0

# %% [markdown]
# Get the summary statistics for numberical columnss

# %%
df.describe()
# Out:
#            Order ID                     Order Date  \
# count  4.999990e+05                         499999
# mean   5.501310e+08  2013-10-15 14:17:53.766947584
# min    1.000029e+08            2010-01-01 00:00:00
# 25%    3.251810e+08            2011-11-23 00:00:00
# 50%    5.491798e+08            2013-10-15 00:00:00
# 75%    7.756280e+08            2015-09-08 00:00:00
# max    9.999995e+08            2017-07-28 00:00:00
# std    2.599601e+08                            NaN
#
#                            Ship Date     Units Sold     Unit Price  \
# count                         499999  499999.000000  499999.000000
# mean   2013-11-09 14:20:50.196100608    4999.129554     266.034784
# min              2010-01-01 00:00:00       1.000000       9.330000
# 25%              2011-12-18 00:00:00    2502.000000      81.730000
# 50%              2013-11-09 00:00:00    4999.000000     154.060000
# 75%              2015-10-03 00:00:00    7497.000000     421.890000
# ...

# %% [markdown]
# Getting the unique values

# %%
df.nunique()
# Out:
# Order ID          499999
# Country              185
# Sales Channel          2
# Order Priority         4
# Order Date          2766
# Ship Date           2816
# Units Sold         10000
# Unit Price            12
# Unit Cost             14
# Sales             118519
# Item                  12
# profit            118516
# dtype: int64

# %% [markdown]
# changing the datatype from float to int

# %%
df["Sales"]=df["Sales"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499999 entries, 0 to 499998
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Order ID        499999 non-null  int64
#  1   Country         499999 non-null  object
#  2   Sales Channel   499999 non-null  object
#  3   Order Priority  499999 non-null  object
#  4   Order Date      499999 non-null  datetime64[ns]
#  5   Ship Date       499999 non-null  datetime64[ns]
#  6   Units Sold      499999 non-null  int64
#  7   Unit Price      499999 non-null  float64
#  8   Unit Cost       499999 non-null  float64
#  9   Sales           499999 non-null  int32
#  10  Item            499999 non-null  object
#  11  profit          499999 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int32(1), int64(2), object(4)
# memory usage: 43.9+ MB

# %% [markdown]
# renaming column

# %%
df.rename(columns={"Sales":"Total Sales"},inplace=True)
df.head(1)
# Out:
#     Order ID   Country Sales Channel Order Priority Order Date  Ship Date  \
# 0  530075585  Ethiopia        Online              H 2010-06-06 2010-07-01
#
#    Units Sold  Unit Price  Unit Cost  Total Sales    Item    profit
# 0       10000      152.58      97.44      1525800  Snacks  551400.0

# %% [markdown]
# To check duplicate rows

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1 = pd.read_excel("Chocolate Sales.xlsx")

# %%
df1.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco 2022-01-04    5320
# 1     Van Tuxwell      India        85% Dark Bars 2022-08-01    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes 2022-07-07    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes 2022-04-27   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes 2022-02-24   13685
#
#    Boxes Shipped  Month
# 0            180      1
# 1             94      8
# 2             91      7
# 3            342      4
# 4            184      2

# %%
df2 = pd.concat([df,df1],axis=0)
df2.columns
# Out:
# Index(['Order ID', 'Country', 'Sales Channel', 'Order Priority', 'Order Date',
#        'Ship Date', 'Units Sold', 'Unit Price', 'Unit Cost', 'Total Sales',
#        'Item', 'profit', 'Sales Person', 'Product', 'Date', 'Amount',
#        'Boxes Shipped', 'Month'],
#       dtype='object')

# %%
df[(df["profit"]>1700000) & (df["Order Priority"]=="H")]
# Out:
#         Order ID                           Country Sales Channel  \
# 15     261322534                           Comoros        Online
# 31     340228402                          Maldives        Online
# 128    878782069                           Andorra       Offline
# 155    553966987                      Sierra Leone        Online
# 174    632872855                      Saudi Arabia        Online
# ...          ...                               ...           ...
# 10773  531426560                          Djibouti        Online
# 10776  977422130                          Slovenia        Online
# 10966  370066583  Saint Vincent and the Grenadines        Online
# 10969  212254846                            Zambia        Online
# 11030  987526118                              Oman       Offline
#
#       Order Priority Order Date  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 15                 H 2016-06-20 2016-06-25       10000       437.2     263.33
# ...

# %%
df.groupby("Order Priority")["Total Sales"].mean()
# Out:
# Order Priority
# C    1.330870e+06
# H    1.331730e+06
# L    1.327535e+06
# M    1.330217e+06
# Name: Total Sales, dtype: float64
